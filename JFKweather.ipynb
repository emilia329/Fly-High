# %%
import pprint
import requests
import config 
import pandas as pd
import warnings
warnings.simplefilter('ignore')
pd.set_option('display.max_columns', None)

# %%
pages1=[]
for unix in range(1546300800, 1577836800, 86400):
    pages1.append(str(f"https://api.darksky.net/forecast/{config.api_key}/40.6413,-73.7781," + str(unix) + "?exclude=currently,flags,alerts,hourly"))

# %%
weather = []
for page in pages1:
    weather.append(requests.get(page))

# %%
weather_json = []
for temp in weather:
    weather_json.append(temp.json())

# %%
results = []
for item in weather_json:
    results = results + item['daily']['data']

# %%
df1 = pd.DataFrame(results)
df1
# Out:
#            time                                summary               icon  \
# 0    1546232400        Rain starting in the afternoon.               rain
# 1    1546318800      Mostly cloudy throughout the day.               rain
# 2    1546405200      Mostly cloudy throughout the day.  partly-cloudy-day
# 3    1546491600      Mostly cloudy throughout the day.               rain
# 4    1546578000                        Rain overnight.  partly-cloudy-day
# ..          ...                                    ...                ...
# 360  1577336400      Mostly cloudy throughout the day.  partly-cloudy-day
# 361  1577422800      Mostly cloudy throughout the day.               rain
# 362  1577509200      Partly cloudy throughout the day.          clear-day
# 363  1577595600  Light rain starting in the afternoon.               rain
# 364  1577682000                    Rain until evening.               rain
#
#      sunriseTime  sunsetTime  moonPhase  precipIntensity  precipIntensityMax  \
# ...

# %%
df1.to_csv('jfkweather.csv', index=False)

# %%
df1.isnull().sum()
# Out:
# time                             0
# summary                          0
# icon                             0
# sunriseTime                      0
# sunsetTime                       0
# moonPhase                        0
# precipIntensity                  0
# precipIntensityMax               0
# precipIntensityMaxTime           0
# precipProbability                0
# precipType                       1
# temperatureHigh                  0
# temperatureHighTime              0
# temperatureLow                   0
# temperatureLowTime               0
# apparentTemperatureHigh          0
# apparentTemperatureHighTime      0
# apparentTemperatureLow           0
# apparentTemperatureLowTime       0
# dewPoint                         0
# humidity                         0
# pressure                         0
# windSpeed                        0
# windGust                         0
# windGustTime                     0
# windBearing                      0
# cloudCover                       0
# ...
