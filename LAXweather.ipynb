# %%
import pprint
import requests
import config 
import pandas as pd

# %%
pages1=[]
for unix in range(1546300800, 1577836800, 86400):
    pages1.append(str(f"https://api.darksky.net/forecast/{config.api_key}/33.9416,-118.4085," + str(unix) + "?exclude=currently,flags,alerts,hourly"))

# %%
weather = []
for page in pages1:
    weather.append(requests.get(page))

# %%
weather_json = []
for temp in weather:
    weather_json.append(temp.json())

# %%
results = []
for item in weather_json:
    results = results + item['daily']['data']

# %%
df1 = pd.DataFrame(results)
df1
# Out:
#            time                            summary               icon  \
# 0    1546243200  Partly cloudy throughout the day.  partly-cloudy-day
# 1    1546329600          Clear throughout the day.          clear-day
# 2    1546416000          Clear throughout the day.          clear-day
# 3    1546502400          Clear throughout the day.          clear-day
# 4    1546588800          Clear throughout the day.          clear-day
# ..          ...                                ...                ...
# 360  1577347200               Rain in the morning.               rain
# 361  1577433600          Clear throughout the day.          clear-day
# 362  1577520000          Clear throughout the day.          clear-day
# 363  1577606400  Partly cloudy throughout the day.  partly-cloudy-day
# 364  1577692800  Partly cloudy throughout the day.  partly-cloudy-day
#
#      sunriseTime  sunsetTime  moonPhase  precipIntensity  precipIntensityMax  \
# ...

# %%
df1.to_csv('laxweather.csv', index=False)

# %%
df1
# Out:
#            time                            summary               icon  \
# 0    1546243200  Partly cloudy throughout the day.  partly-cloudy-day
# 1    1546329600          Clear throughout the day.          clear-day
# 2    1546416000          Clear throughout the day.          clear-day
# 3    1546502400          Clear throughout the day.          clear-day
# 4    1546588800          Clear throughout the day.          clear-day
# ..          ...                                ...                ...
# 360  1577347200               Rain in the morning.               rain
# 361  1577433600          Clear throughout the day.          clear-day
# 362  1577520000          Clear throughout the day.          clear-day
# 363  1577606400  Partly cloudy throughout the day.  partly-cloudy-day
# 364  1577692800  Partly cloudy throughout the day.  partly-cloudy-day
#
#      sunriseTime  sunsetTime  moonPhase  precipIntensity  precipIntensityMax  \
# ...
