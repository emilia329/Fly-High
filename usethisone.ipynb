# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

newyork= pd.read_csv('newyork.csv')
newyork
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0            1501        1      1            24            4  2019-01-24
# 1            1517        1      1            24            4  2019-01-24
# 2            1527        1      1            24            4  2019-01-24
# 3            1539        1      1            24            4  2019-01-24
# 4            1545        1      1            24            4  2019-01-24
# ...           ...      ...    ...           ...          ...         ...
# 25661       65625        4     12            31            2  2019-12-31
# 25662       65644        4     12            31            2  2019-12-31
# 25663       65658        4     12            31            2  2019-12-31
# 25664       65673        4     12            31            2  2019-12-31
# 25665       65711        4     12            31            2  2019-12-31
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %%
newjersey = pd.read_csv('newjersey.csv')
newjersey
# Out:
#       Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0            530        1      1            26            6  2019-01-26
# 1            539        1      1            26            6  2019-01-26
# 2            549        1      1            26            6  2019-01-26
# 3            556        1      1            26            6  2019-01-26
# 4            566        1      1            26            6  2019-01-26
# ...          ...      ...    ...           ...          ...         ...
# 9902       26223        4     12             8            7  2019-12-08
# 9903       26245        4     12             8            7  2019-12-08
# 9904       26278        4     12             8            7  2019-12-08
# 9905       26348        4     12             8            7  2019-12-08
# 9906       26357        4     12             8            7  2019-12-08
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %%
frames = [newyork,newjersey]

df = pd.concat(frames)

# %%
cols = ['DEP_TIME','DEP_DELAY', 'ARR_TIME', 'ARR_DELAY' ,'CANCELLED', 'AIR_TIME']
def cancelled(df):
    df['CANCELLED']==1
    df[cols]=df[cols].fillna(0)
    return df

# %%
df = cancelled(df)
df
# Out:
#       Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0           1501        1      1            24            4  2019-01-24
# 1           1517        1      1            24            4  2019-01-24
# 2           1527        1      1            24            4  2019-01-24
# 3           1539        1      1            24            4  2019-01-24
# 4           1545        1      1            24            4  2019-01-24
# ...          ...      ...    ...           ...          ...         ...
# 9902       26223        4     12             8            7  2019-12-08
# 9903       26245        4     12             8            7  2019-12-08
# 9904       26278        4     12             8            7  2019-12-08
# 9905       26348        4     12             8            7  2019-12-08
# 9906       26357        4     12             8            7  2019-12-08
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %%
df.to_csv('concatdata.csv')

# %%
df['delayed'] = df['DEP_DELAY'].apply(lambda x: 'true' if x > 0 else 'false')

# %%
df['ontime'] = df['DEP_DELAY'].apply(lambda x: 'true' if x < 0 else 'false')

# %%
df['cancel'] = df['CANCELLED'].apply(lambda x: 'true' if x >= 1 else 'false')

# %%
df
# Out:
#       Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0           1501        1      1            24            4  2019-01-24
# 1           1517        1      1            24            4  2019-01-24
# 2           1527        1      1            24            4  2019-01-24
# 3           1539        1      1            24            4  2019-01-24
# 4           1545        1      1            24            4  2019-01-24
# ...          ...      ...    ...           ...          ...         ...
# 9902       26223        4     12             8            7  2019-12-08
# 9903       26245        4     12             8            7  2019-12-08
# 9904       26278        4     12             8            7  2019-12-08
# 9905       26348        4     12             8            7  2019-12-08
# 9906       26357        4     12             8            7  2019-12-08
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %%
df[(df['delayed'] == 'true') & (df['CANCELLED'] ==1)]
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 13161         880        3      7             6            6  2019-07-06
# 13477       18748        3      7             6            6  2019-07-06
# 20311       39740        4     10            31            4  2019-10-31
# 21025       53924        4     10            31            4  2019-10-31
# 5064        12194        3      7            21            7  2019-07-21
# 5267        19353        3      7             6            6  2019-07-06
# 6487         1146        3      9            13            5  2019-09-13
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 13161                AA                331              12478    JFK
# 13477                AA                  3              12478    JFK
# 20311                AA                 24              12478    JFK
# 21025                AA                247              12478    JFK
# ...

# %%
def classifier(row):
    if row['cancel'] == 'true':
        return 1
    elif row['delayed'] == 'true':
        return 2
    elif row['ontime'] == 'true':
        return 3

# %%
df['class']= df.apply(classifier,axis=1)

# %%
df.to_csv('cleanedclass.csv')

# %%
df['class'].value_counts()
# Out:
# 3.0    21646
# 2.0    11957
# 1.0      196
# Name: class, dtype: int64

# %%
df[(df['CANCELLED'] == 1) & (df['DEP_DELAY'] >0)]
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 13161         880        3      7             6            6  2019-07-06
# 13477       18748        3      7             6            6  2019-07-06
# 20311       39740        4     10            31            4  2019-10-31
# 21025       53924        4     10            31            4  2019-10-31
# 5064        12194        3      7            21            7  2019-07-21
# 5267        19353        3      7             6            6  2019-07-06
# 6487         1146        3      9            13            5  2019-09-13
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 13161                AA                331              12478    JFK
# 13477                AA                  3              12478    JFK
# 20311                AA                 24              12478    JFK
# 21025                AA                247              12478    JFK
# ...

# %%
df['delayed'].value_counts()
# Out:
# false    23609
# true     11964
# Name: delayed, dtype: int64

# %%
EWR= df[df['ORIGIN_STATE_ABR'] == 'NJ']
EWR
# Out:
#       Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0            530        1      1            26            6  2019-01-26
# 1            539        1      1            26            6  2019-01-26
# 3            556        1      1            26            6  2019-01-26
# 7            598        1      1            26            6  2019-01-26
# 9            607        1      1            25            5  2019-01-25
# ...          ...      ...    ...           ...          ...         ...
# 9899       26195        4     12             8            7  2019-12-08
# 9902       26223        4     12             8            7  2019-12-08
# 9903       26245        4     12             8            7  2019-12-08
# 9904       26278        4     12             8            7  2019-12-08
# 9905       26348        4     12             8            7  2019-12-08
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %%
EWR['MONTH'].value_counts()
# Out:
# 10    445
# 7     444
# 8     444
# 5     439
# 12    431
# 6     428
# 9     426
# 4     420
# 11    416
# 3     395
# 1     351
# 2     316
# Name: MONTH, dtype: int64

# %%
EWR['OP_UNIQUE_CARRIER'].value_counts().plot(kind='bar')

# %%
EWR['AIR_TIME'].describe()
# Out:
# count    4955.000000
# mean      320.125933
# std        36.713479
# min         0.000000
# 25%       311.000000
# 50%       322.000000
# 75%       334.000000
# max       401.000000
# Name: AIR_TIME, dtype: float64

# %%
#average 5 hours 21 mins 
EWR[EWR['AIR_TIME']==EWR['AIR_TIME'].max()]
#6hours 41 mins
# Out:
#       Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 1858       22119        1      3             2            6  2019-03-02
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 1858                AS               1161              11618    EWR
#
#      ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST  \
# 1858       Newark, NJ               NJ      New Jersey            12892  LAX
#
#        DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  DEP_TIME  DEP_DELAY  \
# 1858  Los Angeles, CA             CA    California     747.0       17.0
#
#       ARR_TIME  ARR_DELAY  CANCELLED  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 1858    1245.0      110.0        0.0     401.0    2454.0           17.0
#
#       WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY delayed  \
# 1858            0.0       93.0             0.0                  0.0    true
#
#      ontime cancel  class
# 1858  false  false    2.0

# %%
EWR['OP_UNIQUE_CARRIER'].value_counts()
# Out:
# UA    3950
# AS    1005
# Name: OP_UNIQUE_CARRIER, dtype: int64

# %%
JFK = df[df['ORIGIN_STATE_ABR'] == 'NY']
JFK
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 1            1517        1      1            24            4  2019-01-24
# 3            1539        1      1            24            4  2019-01-24
# 4            1545        1      1            24            4  2019-01-24
# 5            1554        1      1            24            4  2019-01-24
# 6            1560        1      1            24            4  2019-01-24
# ...           ...      ...    ...           ...          ...         ...
# 25653       65551        4     12            30            1  2019-12-30
# 25655       65560        4     12            30            1  2019-12-30
# 25658       65598        4     12            31            2  2019-12-31
# 25660       65624        4     12            31            2  2019-12-31
# 25665       65711        4     12            31            2  2019-12-31
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %%
JFK['MONTH'].value_counts()
# Out:
# 3     1125
# 10    1106
# 5     1097
# 12    1096
# 4     1070
# 1     1064
# 6     1061
# 11    1049
# 9     1047
# 8     1047
# 7     1043
# 2      999
# Name: MONTH, dtype: int64

# %%
JFK['MONTH'].value_counts().plot(kind='bar')

# %%
JFK['AIR_TIME'].describe()
# Out:
# count    12804.000000
# mean       330.897844
# std         35.599230
# min          0.000000
# 25%        320.000000
# 50%        332.000000
# 75%        345.000000
# max        416.000000
# Name: AIR_TIME, dtype: float64

# %%
#average 5 hours 31 mins
JFK[JFK['AIR_TIME']==JFK['AIR_TIME'].max()]
#6hours 56 mins
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 23089       53739        4     11            27            3  2019-11-27
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 23089                AA                331              12478    JFK
#
#       ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST  \
# 23089     New York, NY               NY        New York            12892  LAX
#
#         DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  DEP_TIME  DEP_DELAY  \
# 23089  Los Angeles, CA             CA    California    1055.0       -5.0
#
#        ARR_TIME  ARR_DELAY  CANCELLED  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 23089    1539.0       81.0        0.0     416.0    2475.0            0.0
#
#        WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY delayed  \
# 23089            0.0       81.0             0.0                  0.0   false
#
#       ontime cancel  class
# 23089   true  false    3.0

# %%
LAX = df[df['ORIGIN_STATE_ABR'] == 'CA']
LAX
# Out:
#       Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0           1501        1      1            24            4  2019-01-24
# 2           1527        1      1            24            4  2019-01-24
# 7           1567        1      1            24            4  2019-01-24
# 9           1596        1      1            25            5  2019-01-25
# 11          1622        1      1            25            5  2019-01-25
# ...          ...      ...    ...           ...          ...         ...
# 9896       26147        4     12             8            7  2019-12-08
# 9898       26191        4     12             8            7  2019-12-08
# 9900       26208        4     12             8            7  2019-12-08
# 9901       26221        4     12             8            7  2019-12-08
# 9906       26357        4     12             8            7  2019-12-08
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %%
LAX['AIR_TIME'].describe()
# Out:
# count    17814.000000
# mean       284.044235
# std         33.682242
# min          0.000000
# 25%        276.000000
# 50%        287.000000
# 75%        297.000000
# max        427.000000
# Name: AIR_TIME, dtype: float64

# %%
LAX['AIR_TIME'].max()
# Out:
# 427.0

# %%
#7 hours 7 minutes 
#averge 4 hours 46 mins
LAX[LAX['AIR_TIME']==LAX['AIR_TIME'].max()]
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 16199       34105        3      8             8            4  2019-08-08
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 16199                AA                274              12892    LAX
#
#       ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST  \
# 16199  Los Angeles, CA               CA      California            12478  JFK
#
#       DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  DEP_TIME  DEP_DELAY  \
# 16199   New York, NY             NY      New York    1225.0       25.0
#
#        ARR_TIME  ARR_DELAY  CANCELLED  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 16199    2307.0      136.0        0.0     427.0    2475.0            9.0
#
#        WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY delayed  \
# 16199            0.0      111.0             0.0                 16.0    true
#
#       ontime cancel  class
# 16199  false  false    2.0

# %%
LAX['MONTH'].value_counts()
# Out:
# 10    1552
# 5     1536
# 12    1525
# 8     1523
# 3     1522
# 7     1511
# 4     1491
# 6     1488
# 9     1473
# 11    1465
# 1     1413
# 2     1315
# Name: MONTH, dtype: int64

# %%
def Airlines(df):
    df.value_counts().plot(kind='bar',title='AIRLINES', color ='lightsalmon')
    plt.xlabel("AIRLINES")
    plt.ylabel("FREQU")

# %%
graphs(JFK['OP_UNIQUE_CARRIER'])

# %%
graphs(LAX['OP_UNIQUE_CARRIER'])

# %%
graphs(EWR['OP_UNIQUE_CARRIER'])

# %%
graphs(df['OP_UNIQUE_CARRIER'])

# %%
df
# Out:
#       Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0           1501        1      1            24            4  2019-01-24
# 1           1517        1      1            24            4  2019-01-24
# 2           1527        1      1            24            4  2019-01-24
# 3           1539        1      1            24            4  2019-01-24
# 4           1545        1      1            24            4  2019-01-24
# ...          ...      ...    ...           ...          ...         ...
# 9902       26223        4     12             8            7  2019-12-08
# 9903       26245        4     12             8            7  2019-12-08
# 9904       26278        4     12             8            7  2019-12-08
# 9905       26348        4     12             8            7  2019-12-08
# 9906       26357        4     12             8            7  2019-12-08
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %%
JFK['QUARTER'].value_counts()
# Out:
# 4    3251
# 2    3228
# 1    3188
# 3    3137
# Name: QUARTER, dtype: int64

# %%
JFK['DAY_OF_WEEK'].value_counts()
# Out:
# 5    1901
# 1    1901
# 2    1897
# 4    1895
# 3    1895
# 7    1856
# 6    1459
# Name: DAY_OF_WEEK, dtype: int64

# %%
JFK
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 1            1517        1      1            24            4  2019-01-24
# 3            1539        1      1            24            4  2019-01-24
# 4            1545        1      1            24            4  2019-01-24
# 5            1554        1      1            24            4  2019-01-24
# 6            1560        1      1            24            4  2019-01-24
# ...           ...      ...    ...           ...          ...         ...
# 25653       65551        4     12            30            1  2019-12-30
# 25655       65560        4     12            30            1  2019-12-30
# 25658       65598        4     12            31            2  2019-12-31
# 25660       65624        4     12            31            2  2019-12-31
# 25665       65711        4     12            31            2  2019-12-31
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# ...

# %% [markdown]
#  CarrierDelay:	Carrier Delay, in Minutes
#  WeatherDelay:	Weather Delay, in Minutes
#  NASDelay:	National Air System Delay, in Minutes
#  SecurityDelay:	Security Delay, in Minutes
#  LateAircraftDelay:	Late Aircraft Delay, in Minutes

# %%
#average 5 hours 31 mins
JFK[JFK['AIR_TIME']==JFK['AIR_TIME'].max()]
#6hours 56 mins
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 23089       53739        4     11            27            3  2019-11-27
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 23089                AA                331              12478    JFK
#
#       ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST  \
# 23089     New York, NY               NY        New York            12892  LAX
#
#         DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  DEP_TIME  DEP_DELAY  \
# 23089  Los Angeles, CA             CA    California    1055.0       -5.0
#
#        ARR_TIME  ARR_DELAY  CANCELLED  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 23089    1539.0       81.0        0.0     416.0    2475.0            0.0
#
#        WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY delayed  \
# 23089            0.0       81.0             0.0                  0.0   false
#
#       ontime cancel  class
# 23089   true  false    3.0

# %%
#7 hours 7 minutes 
#averge 4 hours 46 mins
LAX[LAX['AIR_TIME']==LAX['AIR_TIME'].max()]
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 16199       34105        3      8             8            4  2019-08-08
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 16199                AA                274              12892    LAX
#
#       ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST  \
# 16199  Los Angeles, CA               CA      California            12478  JFK
#
#       DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  DEP_TIME  DEP_DELAY  \
# 16199   New York, NY             NY      New York    1225.0       25.0
#
#        ARR_TIME  ARR_DELAY  CANCELLED  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 16199    2307.0      136.0        0.0     427.0    2475.0            9.0
#
#        WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY delayed  \
# 16199            0.0      111.0             0.0                 16.0    true
#
#       ontime cancel  class
# 16199  false  false    2.0

# %%
#average 5 hours 21 mins 
EWR[EWR['AIR_TIME']==EWR['AIR_TIME'].max()]
#6hours 41 mins
# Out:
#       Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 1858       22119        1      3             2            6  2019-03-02
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 1858                AS               1161              11618    EWR
#
#      ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST  \
# 1858       Newark, NJ               NJ      New Jersey            12892  LAX
#
#        DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  DEP_TIME  DEP_DELAY  \
# 1858  Los Angeles, CA             CA    California     747.0       17.0
#
#       ARR_TIME  ARR_DELAY  CANCELLED  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 1858    1245.0      110.0        0.0     401.0    2454.0           17.0
#
#       WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY delayed  \
# 1858            0.0       93.0             0.0                  0.0    true
#
#      ontime cancel  class
# 1858  false  false    2.0

# %%
JFK[['CARRIER_DELAY','WEATHER_DELAY','NAS_DELAY','SECURITY_DELAY','LATE_AIRCRAFT_DELAY']]
# Out:
#        CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 1                NaN            NaN        NaN             NaN
# 3                NaN            NaN        NaN             NaN
# 4                1.0            0.0        0.0             0.0
# 5                0.0            0.0       40.0             0.0
# 6                NaN            NaN        NaN             NaN
# ...              ...            ...        ...             ...
# 25653            NaN            NaN        NaN             NaN
# 25655          121.0            0.0        0.0             0.0
# 25658            NaN            NaN        NaN             NaN
# 25660            NaN            NaN        NaN             NaN
# 25665            NaN            NaN        NaN             NaN
#
#        LATE_AIRCRAFT_DELAY
# 1                      NaN
# 3                      NaN
# 4                     65.0
# 5                     97.0
# 6                      NaN
# ...                    ...
# ...

# %%
JFK[JFK['CARRIER_DELAY']==JFK['CARRIER_DELAY'].max()]
# Out:
#        Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 16843       61078        3      8            22            4  2019-08-22
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  \
# 16843                DL                975              12478    JFK
#
#       ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST  \
# 16843     New York, NY               NY        New York            12892  LAX
#
#         DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  DEP_TIME  DEP_DELAY  \
# 16843  Los Angeles, CA             CA    California    1107.0     1177.0
#
#        ARR_TIME  ARR_DELAY  CANCELLED  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 16843    1348.0     1138.0        0.0     303.0    2475.0         1138.0
#
#        WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY delayed  \
# 16843            0.0        0.0             0.0                  0.0    true
#
#       ontime cancel  class
# 16843  false  false    2.0
